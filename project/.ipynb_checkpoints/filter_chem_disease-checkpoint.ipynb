# %%
import pandas as pd
from typing import List, Dict

# %%
def normalize_column_names(columns):
    return [column.lower() for column in columns]
    

def add_index(df):
    df.index.rename('id', inplace=True)
    df.index += 1
    return

# %% [markdown]
# ## Loading chemical diseases table and filtering it

# %%
columns_cd_str = "ChemicalName,ChemicalID,CasRN,DiseaseName,DiseaseID,DirectEvidence,InferenceGeneSymbol,InferenceScore,OmimIDs,PubMedIDs"
columns_cd = columns_cd_str.split(",")
columns_final_cd = normalize_column_names(columns_cd)

column_cd_dtype = {"chemicalname": str,
                "chemicalid": str,
                "casrn": str,
                "diseasename": str,
                "diseaseid": str,
                "directevidence": str,
                "inferencegenesymbol": str,
                "inferencescore": str,
                "omimids": str,
                "pubmedids": str}
                
df_chem_diseases = pd.read_csv("http://ctdbase.org/reports/CTD_chemicals_diseases.tsv.gz", 
                               compression='gzip', header=0, sep='\t', comment='#', names=columns_final_cd, 
                               low_memory=False, dtype=column_cd_dtype)
df_chem_diseases.head(3)
# Out:
#   chemicalname chemicalid casrn             diseasename        diseaseid  \
# 0     10074-G5    C534883   NaN          Adenocarcinoma     MESH:D000230
# 1     10074-G5    C534883   NaN  Adenocarcinoma of Lung  MESH:D000077192
# 2     10074-G5    C534883   NaN                Alopecia     MESH:D000505
#
#   directevidence inferencegenesymbol inferencescore omimids          pubmedids
# 0            NaN                 MYC           4.09     NaN           26432044
# 1            NaN                 MYC           4.32     NaN  26656844|27602772
# 2            NaN                  AR           4.50     NaN           15902657

# %%
df_chem_diseases = df_chem_diseases[df_chem_diseases['casrn'].notna()]
df_chem_diseases.head(3)
# Out:
#                                           chemicalname chemicalid       casrn  \
# 121  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 122  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 123  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
#
#                        diseasename     diseaseid directevidence  \
# 121    Abnormalities, Drug-Induced  MESH:D000014            NaN
# 122              Acute Lung Injury  MESH:D055371            NaN
# 123  Amphetamine-Related Disorders  MESH:D019969            NaN
#
#     inferencegenesymbol inferencescore omimids pubmedids
# 121               EPHX1           5.15     NaN   2336087
# 122               EPHX1           5.37     NaN  26840748
# 123               EPHX1           5.44     NaN  19598248

# %%
df_chem_diseases.drop(labels=['chemicalname', 'casrn', 'directevidence', 'inferencegenesymbol', 'omimids', 'pubmedids'],\
                      axis=1, inplace=True)

# %%
df_chem_diseases
# Out:
#         chemicalid                                        diseasename  \
# 121        C004822                        Abnormalities, Drug-Induced
# 122        C004822                                  Acute Lung Injury
# 123        C004822                      Amphetamine-Related Disorders
# 124        C004822                                          Carcinoma
# 125        C004822                          Carcinoma, Hepatocellular
# ...            ...                                                ...
# 7805137    C015582                           Bone Diseases, Metabolic
# 7805138    C015582                                        Cholestasis
# 7805139    C015582                                    Liver Cirrhosis
# 7805140    C015582  MICROCEPHALY, CONGENITAL CATARACT, AND PSORIAS...
# 7805141    C015582                    Xanthomatosis, Cerebrotendinous
#
#             diseaseid inferencescore
# 121      MESH:D000014           5.15
# 122      MESH:D055371           5.37
# 123      MESH:D019969           5.44
# 124      MESH:D002277           5.06
# 125      MESH:D006528           4.58
# ...               ...            ...
# 7805137  MESH:D001851           5.99
# 7805138  MESH:D002779           4.91
# 7805139  MESH:D008103           4.98
# 7805140   OMIM:616834           7.81
# 7805141  MESH:D019294           7.91
#
# [5343993 rows x 4 columns]

# %%
filteredcontains = df_chem_diseases[df_chem_diseases['diseasename'].str.contains("PARKINSON")]
filteredcontains
# Out:
#         chemicalid                                        diseasename  \
# 23008      C026486            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
# 23010      C026486                      PARKINSON DISEASE, LATE-ONSET
# 27075      C025603            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
# 33580      C048792                      PARKINSON DISEASE, LATE-ONSET
# 41220      D019813  AMYOTROPHIC LATERAL SCLEROSIS-PARKINSONISM/DEM...
# ...            ...                                                ...
# 7758912    D015032                      PARKINSON DISEASE, LATE-ONSET
# 7762845    D019345                      PARKINSON DISEASE, LATE-ONSET
# 7772489    D015034                      PARKINSON DISEASE, LATE-ONSET
# 7780631    D019287  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
# 7787490    D015039            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
#
#            diseaseid inferencescore
# 23008    OMIM:168601           4.65
# 23010    OMIM:168600           3.53
# 27075    OMIM:168601           6.16
# 33580    OMIM:168600           6.20
# 41220    OMIM:105500           3.64
# ...              ...            ...
# 7758912  OMIM:168600           6.17
# 7762845  OMIM:168600           4.30
# 7772489  OMIM:168600           3.93
# 7780631  OMIM:613643           4.84
# 7787490  OMIM:168601           5.48
#
# [1628 rows x 4 columns]

# %% [markdown]
# ### Loading chemical gene table and filtering it

# %%
columns_cg_str = "ChemicalName,ChemicalID,CasRN,GeneSymbol,GeneID,GeneForms,Organism,OrganismID,Interaction,InteractionActions,PubMedIDs"
columns_cg = columns_cg_str.split(",")

column_cg_dtype = {"ChemicalName": str,
                "ChemicalID": str,
                "CasRN": str,
                "GeneSymbol": str,
                "GeneID": str,
                "GeneForms": str,
                "Organism": str,
                "OrganismID": str,
                "Interaction": str,
                "InteractionActions": str,
                "PubMedIDs": str}
df_chem_gene = pd.read_csv("http://ctdbase.org/reports/CTD_chem_gene_ixns.tsv.gz", compression='gzip', header=0, sep='\t', comment='#', names=columns_cg, low_memory=False, dtype=column_cg_dtype)
df_chem_gene = df_chem_gene.loc[df_chem_gene['Organism'] == 'Homo sapiens']
df_chem_gene.head(3)
# Out:
#   ChemicalName ChemicalID CasRN GeneSymbol GeneID GeneForms      Organism  \
# 0     10074-G5    C534883   NaN         AR    367   protein  Homo sapiens
# 1     10074-G5    C534883   NaN         AR    367   protein  Homo sapiens
# 2     10074-G5    C534883   NaN         AR    367   protein  Homo sapiens
#
#   OrganismID                                        Interaction  \
# 0       9606  10074-G5 inhibits the reaction [EPHB2 protein ...
# 1       9606  10074-G5 results in decreased expression of AR...
# 2       9606  10074-G5 results in decreased expression of AR...
#
#                         InteractionActions PubMedIDs
# 0  decreases^reaction|increases^expression  32184358
# 1                     decreases^expression  32184358
# 2                     decreases^expression  32184358

# %%
df_chem_gene = df_chem_gene[df_chem_gene['CasRN'].notna()]
df_chem_gene
# Out:
#                                               ChemicalName ChemicalID  \
# 19       10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822
# 20       10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822
# 50           10-(alpha-diethylaminopropionyl)phenothiazine    C013759
# 52                               10-decarbamoylmitomycin C    C067795
# 53                               10-decarbamoylmitomycin C    C067795
# ...                                                    ...        ...
# 2320048                                            Zymosan    D015054
# 2320060                                            Zymosan    D015054
# 2320067                                            Zymosan    D015054
# 2320068                                         zymosterol    C015582
# 2320069                                         zymosterol    C015582
#
#               CasRN GeneSymbol GeneID GeneForms      Organism OrganismID  \
# 19       35079-97-1      EPHX1   2052      gene  Homo sapiens       9606
# 20       35079-97-1      EPHX1   2052   protein  Homo sapiens       9606
# 50       63834-04-8       HAMP  57817      mRNA  Homo sapiens       9606
# 52       26909-37-5      CASP3    836   protein  Homo sapiens       9606
# 53       26909-37-5      CASP9    842   protein  Homo sapiens       9606
# ...             ...        ...    ...       ...           ...        ...
# 2320048   9010-72-4   TNFRSF1A   7132   protein  Homo sapiens       9606
# 2320060   9010-72-4   TNFRSF1B   7133   protein  Homo sapiens       9606
# 2320067   9010-72-4       XIAP    331      mRNA  Homo sapiens       9606
# 2320068    128-33-6    CYP27A1   1593   protein  Homo sapiens       9606
# 2320069    128-33-6      MSMO1   6307   protein  Homo sapiens       9606
#
#                                                Interaction  \
# 19       [EPHX1 gene SNP affects the metabolism of carb...
# 20       [EPHX1 protein results in increased metabolism...
# 50       10-(alpha-diethylaminopropionyl)phenothiazine ...
# 52       10-decarbamoylmitomycin C results in increased...
# 53       10-decarbamoylmitomycin C results in increased...
# ...                                                    ...
# 2320048  Zymosan results in increased expression of TNF...
# 2320060  Zymosan results in increased expression of TNF...
# 2320067  Zymosan analog results in decreased expression...
# 2320068  CYP27A1 protein results in increased metabolis...
# 2320069  MSMO1 protein results in decreased abundance o...
#
#                                         InteractionActions PubMedIDs
# 19       affects^chemical synthesis|affects^metabolic p...  15692831
# 20       increases^chemical synthesis|increases^metabol...  15692831
# 50                                    decreases^expression  25633564
# 52                                      increases^activity  17530733
# 53                                      increases^activity  17530733
# ...                                                    ...       ...
# 2320048                               increases^expression  10072544
# 2320060                               increases^expression  10072544
# 2320067                               decreases^expression  16803582
# 2320068                     increases^metabolic processing  14622972
# 2320069                                decreases^abundance  23125191
#
# [726136 rows x 11 columns]

# %%
df_chem_gene['IntAct'] = df_chem_gene.InteractionActions.str.split('|')
df_chemical_gene = df_chem_gene.explode('IntAct')
df_chemical_gene.drop(labels=['InteractionActions', 'GeneForms', 'PubMedIDs'], axis=1, inplace=True)
df_chemical_gene.rename(columns={'IntAct': 'InteractionActions'}, inplace=True)
df_chemical_gene.head()
# Out:
#                                          ChemicalName ChemicalID       CasRN  \
# 19  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 19  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 20  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 20  10,11-dihydro-10,11-dihydroxy-5H-dibenzazepine...    C004822  35079-97-1
# 50      10-(alpha-diethylaminopropionyl)phenothiazine    C013759  63834-04-8
#
#    GeneSymbol GeneID      Organism OrganismID  \
# 19      EPHX1   2052  Homo sapiens       9606
# 19      EPHX1   2052  Homo sapiens       9606
# 20      EPHX1   2052  Homo sapiens       9606
# 20      EPHX1   2052  Homo sapiens       9606
# 50       HAMP  57817  Homo sapiens       9606
#
#                                           Interaction  \
# 19  [EPHX1 gene SNP affects the metabolism of carb...
# 19  [EPHX1 gene SNP affects the metabolism of carb...
# 20  [EPHX1 protein results in increased metabolism...
# 20  [EPHX1 protein results in increased metabolism...
# 50  10-(alpha-diethylaminopropionyl)phenothiazine ...
#
#                 InteractionActions
# 19      affects^chemical synthesis
# 19    affects^metabolic processing
# 20    increases^chemical synthesis
# 20  increases^metabolic processing
# 50            decreases^expression

# %% [markdown]
# ### Function get_cas_id() to get those chemicals that are assosiated with most up or down regulated genes

# %%
gene_list =[ 'UCHL1', 'PDPK1']
interaction_type ='increases^expression'

def get_cas_ids(hgnc_symbols:List,interaction_type:str = None) -> Dict:
    
    ##################### filtering needed data #####################
    searched=df_chemical_gene[df_chemical_gene['GeneSymbol'].isin(gene_list)]
    searched = searched[['GeneSymbol', 'ChemicalID', 'CasRN', 'InteractionActions']]
    searched=searched.loc[searched['InteractionActions'] == interaction_type]
    cleaned=searched.drop_duplicates(keep=False)


    ##################### initializing empty dictionary ############# 
    hgnc_symbols=cleaned['GeneSymbol'].unique().tolist()
    chemical_gene_interactions = {}
    for hgnc_symbol in hgnc_symbols:
        chemical_gene_interactions[hgnc_symbol]=[]
   

    #################################################################
    # below I would like to generate the dictionary that you decided manually to create
    for index, row in cleaned.iterrows():
        gene = (row['GeneSymbol'])
        chemicalid = row["ChemicalID"]
        cas_id = row["CasRN"]
        interaction=row['InteractionActions']
        chemical_gene_interactions[gene].append({'chemical_id': chemicalid, 'cas_id': cas_id, 'interaction': interaction})

    return chemical_gene_interactions
    
 
get_cas_ids(gene_list,interaction_type)
# Out:
# {'UCHL1': [{'chemical_id': 'D000082',
#    'cas_id': '103-90-2',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D020106',
#    'cas_id': '79-06-1',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D016604',
#    'cas_id': '1162-65-8',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'C000228',
#    'cas_id': '313-67-7',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D001151',
#    'cas_id': '7440-38-2',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D000077237',
#    'cas_id': '1327-53-3',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D001564',
#    'cas_id': '50-32-8',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D003035',
#    'cas_id': '7440-48-4',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D003300',
#    'cas_id': '7440-50-8',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D019327',
#    'cas_id': '7758-98-7',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D016572',
#    'cas_id': '59865-13-3',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D000077209',
#    'cas_id': '2353-33-5',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D008769',
#    'cas_id': '70-25-7',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'C049032',
#    'cas_id': '102-61-4',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'C006253',
#    'cas_id': '50892-23-4',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'C017947',
#    'cas_id': '13768-07-5',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'C002802',
#    'cas_id': '11130-73-7',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D014810',
#    'cas_id': '1406-18-4',
#    'interaction': 'increases^expression'}],
#  'PDPK1': [{'chemical_id': 'C000228',
#    'cas_id': '313-67-7',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D002104',
#    'cas_id': '7440-43-9',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D019256',
#    'cas_id': '10108-64-2',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D003300',
#    'cas_id': '7440-50-8',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D014520',
#    'cas_id': '51-79-6',
#    'interaction': 'increases^expression'},
#   {'chemical_id': 'D014635',
#    'cas_id': '99-66-1',
#    'interaction': 'increases^expression'}]}

# %%
# http://ctdbase.org/detail.go?type=disease&acc=MESH:D010300
disease = 'PARKINSON'

def filter_chemical_disease_association(chemical_ids, disease):
    """Filters out chemical ids that do not correspond to Parkinson's 
        disease from the chmeical_disease_associations table
        Returns
        -------
        filtered_chemical_ids: List
            List of chemical ids that are associated with Parkinson's disease.            
    """
    ################# take previous dataframe and take chemicalid from there ########################
    # search for them in chem diseases dataframe
    # search for those that have parkinson disease    
    filteredcontains = df_chem_diseases[df_chem_diseases['diseasename'].str.contains(disease)]
    diction =get_cas_ids(gene_list,interaction_type)  
    chem_id = set()
    
    for key, value in diction.items():
        for element in diction[key]:
            chem_id.add(element['chemical_id'])

    return list(chem_id)

# %%
chemical_ids=[]
filter_chemical_disease_association(chemical_ids, disease)
# Out:
# ['D001151',
#  'D000077209',
#  'D014520',
#  'C000228',
#  'C002802',
#  'D019327',
#  'D016572',
#  'D019256',
#  'D003035',
#  'C006253',
#  'C017947',
#  'D002104',
#  'D014810',
#  'D000082',
#  'D003300',
#  'D016604',
#  'D001564',
#  'D000077237',
#  'D020106',
#  'C049032',
#  'D014635',
#  'D008769']

# %%
chemical_ids=[]
filteredlist=filter_chemical_disease_association(chemical_ids, disease)
filteredcontains=filteredcontains.loc[filteredcontains['chemicalid'].isin(filteredlist)]
filteredcontains=filteredcontains.drop_duplicates(keep=False)

# %%
filteredcontains.drop('diseaseid', axis=1, inplace=True)

# %%
filteredcontains=filteredcontains.sort_values(by=['inferencescore'])
filteredcontains
# Out:
#         chemicalid                                        diseasename  \
# 1583878    D001564            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
# 7545474    D014635            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
# 7656931    D014810                      PARKINSON DISEASE, LATE-ONSET
# 871860     D000082            PARKINSON DISEASE 1, AUTOSOMAL DOMINANT
# 1583883    D001564  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
# ...            ...                                                ...
# 7656926    D014810  PARKINSON DISEASE 11, AUTOSOMAL DOMINANT, SUSC...
# 2403477    D003035  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
# 4888204    D008769  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
# 7461899    C002802  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
# 5887076    C049032  PARKINSON DISEASE 5, AUTOSOMAL DOMINANT, SUSCE...
#
#         inferencescore
# 1583878           3.13
# 7545474           3.18
# 7656931           3.25
# 871860            3.28
# 1583883           3.33
# ...                ...
# 7656926           5.03
# 2403477           5.31
# 4888204           5.39
# 7461899           5.74
# 5887076           5.94
#
# [129 rows x 3 columns]
